# %%
import pandas as pd
pd.set_option("display.max.columns", None)

iedbfile = pd.read_csv('iedb_data.csv', sep=',', error_bad_lines=False, dtype='unicode')
new_header = iedbfile.iloc[0] 
iedbfile = iedbfile[1:] 
iedbfile.columns = new_header

# %%
#iedbfile['MHC Types Present'].unique()
#iedbfile['Allele Name'].unique() #HLA-A*01:01
#a = iedbfile['Antigen Description'].unique()
df = iedbfile[['Antigen Description', 'MHC Types Present', 'Class', 'Allele Name']]
df
# Out:
# 0      Antigen Description MHC Types Present Class     Allele Name
# 1              TTVYPPSSTAK               NaN     I     HLA-A*03:01
# 2                KLEDLERDL               NaN     I     HLA-A*02:01
# 3                GLIEKNIEL            HLA-A2     I          HLA-A2
# 4                FVFLRNFSL       HLA-A*02:01     I     HLA-A*02:01
# 5                FLFLRNFSL       HLA-A*02:01     I     HLA-A*02:01
# ...                    ...               ...   ...             ...
# 13552     GQVTISVDKSISTAYL               NaN    II  HLA-DRB1*04:01
# 13553  DDSKNMLFLQMNSLKTEDT               NaN    II  HLA-DRB1*04:01
# 13554     IKNKIDGETTDYAAPV               NaN    II  HLA-DRB1*04:01
# 13555      NMLFLQMNSLKTEDT               NaN    II  HLA-DRB1*04:01
# 13556    KNQFSLELNSVTAADTA               NaN    II  HLA-DRB1*04:01
#
# [13556 rows x 4 columns]

# %%
temp = df[(df['Allele Name'] == 'HLA-A*02:01')]
print('HLA-A*02:01: ' + str(temp.shape[0]))
temp = df[(df['Class'] == 'I')]
print('MHC Class I: ' + str(temp.shape[0]))
temp2 = df[(df['Class'] == 'II')]
print('MHC Class II: ' + str(temp2.shape[0]))
print('Total: ' + str(df.shape[0]))
# Out:
# HLA-A*02:01: 2619
# MHC Class I: 7783
# MHC Class II: 5387
# Total: 13556
