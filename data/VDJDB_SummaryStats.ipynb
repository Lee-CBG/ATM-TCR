# %%
import pandas as pd
import numpy as np

# %%
vdjdbfile = pd.read_csv('vdjdb_data.tsv', sep='\t')

# %%
# • Species: Human
# • Chain type: TRB (CDR3-beta), TRA (CDR3-alpha, paired only)
chainTypes = ['TRA', 'TRB']
# • HLA type: HLA-A*02:01, All
HLATypes = ['HLA-A*02:01', None]
# • MHC class: I, II
MHCclasses = ['MHCI', 'MHCII']
# • Score: 0, 1, 2, 3, 1-3
possibleScores = [0, 1, 2, 3, None]
vdjdbfile
# Out:
#        complex.id Gene            CDR3            V          J      Species  \
# 0               0  TRA      CAVTDDKIIF  TRAV12-2*01  TRAJ30*01  HomoSapiens
# 1               0  TRA   CAVDSGGYQKVTF  TRAV12-2*01  TRAJ13*01  HomoSapiens
# 2               0  TRA      CAGGDDKIIF  TRAV12-2*01  TRAJ30*01  HomoSapiens
# 3               0  TRA      CAVKDARLMF  TRAV12-2*01  TRAJ31*01  HomoSapiens
# 4               0  TRA      CAVGSDKIIF  TRAV12-2*01  TRAJ30*01  HomoSapiens
# ...           ...  ...             ...          ...        ...          ...
# 67684       24463  TRA    CWSPFGNEKLTF   TRAV8-2*01  TRAJ48*01  HomoSapiens
# 67685       24464  TRA    CWSPFGNEKLTF   TRAV8-2*01  TRAJ48*01  HomoSapiens
# 67686       24476  TRA    CAVTPDGQKLLF   TRAV1-1*01        NaN  HomoSapiens
# 67687       24494  TRA        SSGNQFYF    TRAV21*01  TRAJ49*01  HomoSapiens
# 67688       24499  TRA  CAGLTTDSWGKFQF    TRAV25*01  TRAJ24*01  HomoSapiens
#
#              MHC A MHC B MHC class     Epitope Epitope gene Epitope species  \
# 0         HLA-A*02   B2M      MHCI   LLWNGPMAV         NS4B             YFV
# 1         HLA-A*02   B2M      MHCI   LLWNGPMAV         NS4B             YFV
# 2         HLA-A*02   B2M      MHCI   LLWNGPMAV         NS4B             YFV
# 3         HLA-A*02   B2M      MHCI   LLWNGPMAV         NS4B             YFV
# 4         HLA-A*02   B2M      MHCI   LLWNGPMAV         NS4B             YFV
# ...            ...   ...       ...         ...          ...             ...
# 67684  HLA-A*11:01   B2M      MHCI  GTSGSPIVNR          NS3           DENV1
# 67685  HLA-A*11:01   B2M      MHCI  GTSGSPIINR          NS3         DENV3/4
# 67686  HLA-A*02:01   B2M      MHCI   NLVPMVATV         pp65             CMV
# 67687     HLA-A*02   B2M      MHCI   NLVPMVATV         pp65             CMV
# 67688     HLA-A*02   B2M      MHCI   NLVPMVATV         pp65             CMV
#
#                                                Reference  \
# 0                                          PMID:28975614
# 1                                          PMID:28975614
# 2                                          PMID:28975614
# 3                                          PMID:28975614
# 4                                          PMID:28975614
# ...                                                  ...
# 67684                                      PMID:28945243
# 67685                                      PMID:28945243
# 67686  https://github.com/antigenomics/vdjdb-db/issue...
# 67687                                      PMID:28623251
# 67688                                      PMID:28623251
#
#                                                   Method  \
# 0      {"frequency": "6/56", "identification": "tetra...
# 1      {"frequency": "1/56", "identification": "tetra...
# 2      {"frequency": "1/56", "identification": "tetra...
# 3      {"frequency": "3/56", "identification": "tetra...
# 4      {"frequency": "4/56", "identification": "tetra...
# ...                                                  ...
# 67684  {"frequency": "", "identification": "tetramer-...
# 67685  {"frequency": "", "identification": "tetramer-...
# 67686  {"frequency": "95%", "identification": "pelime...
# 67687  {"frequency": "67.5%", "identification": "tetr...
# 67688  {"frequency": "3.45%", "identification": "tetr...
#
#                                                     Meta  \
# 0      {"cell.subset": "CD8", "clone.id": "", "donor....
# 1      {"cell.subset": "CD8", "clone.id": "", "donor....
# 2      {"cell.subset": "CD8", "clone.id": "", "donor....
# 3      {"cell.subset": "CD8", "clone.id": "", "donor....
# 4      {"cell.subset": "CD8", "clone.id": "", "donor....
# ...                                                  ...
# 67684  {"cell.subset": "CD3+CD8+CD14-CD19-", "clone.i...
# 67685  {"cell.subset": "CD3+CD8+CD14-CD19-", "clone.i...
# 67686  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 67687  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 67688  {"cell.subset": "CD8+", "clone.id": "", "donor...
#
#                                                  CDR3fix  Score
# 0      {"cdr3": "CAVTDDKIIF", "cdr3_old": "CAVTDDKIIF...      1
# 1      {"cdr3": "CAVDSGGYQKVTF", "cdr3_old": "CAVDSGG...      0
# 2      {"cdr3": "CAGGDDKIIF", "cdr3_old": "CAGGDDKIIF...      0
# 3      {"cdr3": "CAVKDARLMF", "cdr3_old": "CAVKDARLMF...      1
# 4      {"cdr3": "CAVGSDKIIF", "cdr3_old": "CAVGSDKIIF...      1
# ...                                                  ...    ...
# 67684  {"cdr3": "CWSPFGNEKLTF", "cdr3_old": "CWSPFGNE...      2
# 67685  {"cdr3": "CWSPFGNEKLTF", "cdr3_old": "CWSPFGNE...      2
# 67686  {"cdr3": "CAVTPDGQKLLF", "cdr3_old": "CAVTPDGQ...      1
# 67687  {"cdr3": "SSGNQFYF", "cdr3_old": "SSGNQFYF", "...      3
# 67688  {"cdr3": "CAGLTTDSWGKFQF", "cdr3_old": "CAGLTT...      2
#
# [67689 rows x 17 columns]

# %%
# Determine counts for VDJDB
counts = {}
for chain in chainTypes:
    for mhc in MHCclasses:
        for hla in HLATypes:
            if hla == None:
                for score in possibleScores:
                    label = (('Species','Human'), ('Chain', chain), ('MHC', mhc), ('HLA', hla), ('Score', score))
                    if score == None:
                        temp = vdjdbfile[(vdjdbfile['Species'] == 'HomoSapiens') & \
                                         (vdjdbfile['Gene'] == chain) & \
                                         (vdjdbfile['Score'] > 0) & \
                                         (vdjdbfile['MHC class'] == mhc)]
                                        
                        count = 'Pairs:' + str(temp.shape[0]) + \
                                ', Unique CDR3s: ' + str(len(temp['CDR3'].unique())) + \
                                ', Unique epitopes: ' + str(len(temp['Epitope'].unique()))
                        counts[label] = count
                    else:
                        temp = vdjdbfile[(vdjdbfile['Species'] == 'HomoSapiens') & \
                                         (vdjdbfile['Gene'] == chain) & \
                                         (vdjdbfile['MHC class'] == mhc) & \
                                         (vdjdbfile['Score'] == score)]
                        count = 'Pairs:' + str(temp.shape[0]) + \
                                ', Unique CDR3s: ' + str(len(temp['CDR3'].unique())) + \
                                ', Unique epitopes: ' + str(len(temp['Epitope'].unique()))
                        counts[label] = count
                
            else:
                for score in possibleScores:
                    label = (('Species','Human'), ('Chain', chain), ('MHC', mhc), ('HLA', hla), ('Score', score))
                    if score == None:
                        temp = vdjdbfile[(vdjdbfile['Species'] == 'HomoSapiens') & \
                                          (vdjdbfile['Gene'] == chain) & \
                                          (vdjdbfile['MHC A'] == hla) & \
                                          (vdjdbfile['Score'] > 0) & \
                                          (vdjdbfile['MHC class'] == mhc)]
                        count = 'Pairs:' + str(temp.shape[0]) + \
                                ', Unique CDR3s: ' + str(len(temp['CDR3'].unique())) + \
                                ', Unique epitopes: ' + str(len(temp['Epitope'].unique()))
                        counts[label] = count
                    else:
                        temp = vdjdbfile[(vdjdbfile['Species'] == 'HomoSapiens') & \
                                         (vdjdbfile['Gene'] == chain) & \
                                         (vdjdbfile['MHC A'] == hla) & \
                                         (vdjdbfile['MHC class'] == mhc) & \
                                         (vdjdbfile['Score'] == score)]
                        count = 'Pairs:' + str(temp.shape[0]) + \
                                ', Unique CDR3s: ' + str(len(temp['CDR3'].unique())) + \
                                ', Unique epitopes: ' + str(len(temp['Epitope'].unique()))
                        counts[label] = count

# %%
for count in counts:
    print(count)
    print(counts[count])
    print('\n')
# Out:
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 0))
# Pairs:3800, Unique CDR3s: 2484, Unique epitopes: 29
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 1))
# Pairs:445, Unique CDR3s: 264, Unique epitopes: 6
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 2))
# Pairs:13, Unique CDR3s: 7, Unique epitopes: 1
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 3))
# Pairs:5, Unique CDR3s: 1, Unique epitopes: 1
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', None))
# Pairs:463, Unique CDR3s: 268, Unique epitopes: 6
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 0))
# Pairs:26365, Unique CDR3s: 19376, Unique epitopes: 56
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 1))
# Pairs:736, Unique CDR3s: 420, Unique epitopes: 27
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 2))
# Pairs:155, Unique CDR3s: 93, Unique epitopes: 18
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 3))
# Pairs:175, Unique CDR3s: 109, Unique epitopes: 54
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCI'), ('HLA', None), ('Score', None))
# Pairs:1066, Unique CDR3s: 598, Unique epitopes: 77
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 0))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 1))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 2))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 3))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', None))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 0))
# Pairs:589, Unique CDR3s: 532, Unique epitopes: 7
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 1))
# Pairs:198, Unique CDR3s: 154, Unique epitopes: 9
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 2))
# Pairs:28, Unique CDR3s: 11, Unique epitopes: 1
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 3))
# Pairs:30, Unique CDR3s: 20, Unique epitopes: 12
#
#
# (('Species', 'Human'), ('Chain', 'TRA'), ('MHC', 'MHCII'), ('HLA', None), ('Score', None))
# Pairs:256, Unique CDR3s: 175, Unique epitopes: 19
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 0))
# Pairs:5025, Unique CDR3s: 3507, Unique epitopes: 44
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 1))
# Pairs:853, Unique CDR3s: 498, Unique epitopes: 13
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 2))
# Pairs:147, Unique CDR3s: 97, Unique epitopes: 4
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', 3))
# Pairs:71, Unique CDR3s: 24, Unique epitopes: 4
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', 'HLA-A*02:01'), ('Score', None))
# Pairs:1071, Unique CDR3s: 601, Unique epitopes: 13
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 0))
# Pairs:33995, Unique CDR3s: 26924, Unique epitopes: 106
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 1))
# Pairs:3158, Unique CDR3s: 2126, Unique epitopes: 78
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 2))
# Pairs:518, Unique CDR3s: 322, Unique epitopes: 26
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', None), ('Score', 3))
# Pairs:362, Unique CDR3s: 209, Unique epitopes: 63
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCI'), ('HLA', None), ('Score', None))
# Pairs:4038, Unique CDR3s: 2596, Unique epitopes: 123
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 0))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 1))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 2))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', 3))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', 'HLA-A*02:01'), ('Score', None))
# Pairs:0, Unique CDR3s: 0, Unique epitopes: 0
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 0))
# Pairs:1044, Unique CDR3s: 955, Unique epitopes: 10
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 1))
# Pairs:269, Unique CDR3s: 230, Unique epitopes: 9
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 2))
# Pairs:34, Unique CDR3s: 21, Unique epitopes: 2
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', None), ('Score', 3))
# Pairs:33, Unique CDR3s: 26, Unique epitopes: 12
#
#
# (('Species', 'Human'), ('Chain', 'TRB'), ('MHC', 'MHCII'), ('HLA', None), ('Score', None))
# Pairs:336, Unique CDR3s: 268, Unique epitopes: 19

# %%
cleanedData = vdjdbfile[['Epitope', 'CDR3', 'Score']]
cleanedData.loc[cleanedData['Score'] > 0, 'Score'] = 1
cleanedData.to_csv('VDJDB_CleanedData.csv', index=False, header=False, sep='\t')
